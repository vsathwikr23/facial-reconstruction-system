# %%
import os
import numpy as np
import math
from PIL import Image
import cv2
import matplotlib.pyplot as plt

# %%
flags = cv2.INPAINT_TELEA

# %%
image = cv2.imread("complete_image.png")
mask = cv2.imread("damaged_image.png")

# %%
plt.imshow(mask)
plt.axis('off')
plt.title('image')
plt.show()

# %%
mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)

# %%
if image.shape[:2] != mask.shape[:2]:
    # Resize the mask to match image's size
    mask = cv2.resize(mask, (image.shape[1], image.shape[0]), interpolation=cv2.INTER_NEAREST)

# %%
output1 = cv2.inpaint(image, mask, 1, cv2.INPAINT_TELEA)

# %%
plt.imshow(output1)
plt.axis('off')
plt.title('image')
plt.show()

# %%
import os
import numpy as np
import math
from PIL import Image
import cv2
import matplotlib.pyplot as plt
flags = cv2.INPAINT_TELEA
image = cv2.imread("complete_image.png")
mask = cv2.imread("damaged_image.png")
mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)
if image.shape[:2] != mask.shape[:2]:
    # Resize the mask to match image's size
    mask = cv2.resize(mask, (image.shape[1], image.shape[0]), interpolation=cv2.INTER_NEAREST)
output1 = cv2.inpaint(image, mask, 1, cv2.INPAINT_TELEA)
